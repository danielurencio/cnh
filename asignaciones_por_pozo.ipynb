# %% [markdown]
# # Reporte: Producción de asignaciones por pozo

# %% [markdown]
# Tutorial para la automatización de los reportes descargables tanto en formato [excel](https://portal.cnih.cnh.gob.mx/downloads/es_MX/estadisticas/Producci%C3%B3n%20de%20asignaciones%20por%20pozo.xlsx) como en formato [pdf](https://portal.cnih.cnh.gob.mx/downloads/es_MX/estadisticas/Producci%C3%B3n%20de%20asignaciones%20por%20pozo.pdf). Las librerías necesarias son las siguientes.

# %%
#coding="latin1"
from sqlalchemy import create_engine
import xlwings as xw
import pandas as pd
import cx_Oracle

# %% [markdown]
# El primer paso es obtener los datos a través de los siguientes comandos.

# %%
engine = create_engine("oracle://cmde_raw:raw17@172.16.120.3:1521/cnih")
query = u"SELECT FECHA, ASIGNACION_CONTRATO, REGION_FISCAL, CAMPO_OFICIAL, NOMBRE_POZO, CLASIFICACION, API,PETROLEO_MBD, GAS_ASOC_MMPCD, GAS_NASOC_MMPCD, GAS_MMPCD, CONDENSADO_MBD, C1_PERC, C2_PERC, C3_PERC, C4_PERC, IC4_PERC, C5_PLUS_PERC, CO2_PERC, H2S_PERC, N2_PERC, C5_PLUS_BTU_FT3, DIAS_PRODUCCION FROM DATOS_DG_MEDICION WHERE FECHA ='01-09-2017' AND CLASIFICACION = 'Asignación'"
datos = pd.read_sql(query,engine)
datos.head()
# Out:
#        fecha     asignacion_contrato              region_fiscal campo_oficial  \
# 0 2017-09-01  A-0394 - Tierra Blanca  Paleocanal de Chicontepec   Cerro Viejo
# 1 2017-09-01  A-0394 - Tierra Blanca  Paleocanal de Chicontepec   Cerro Viejo
# 2 2017-09-01  A-0394 - Tierra Blanca  Paleocanal de Chicontepec         Gallo
# 3 2017-09-01  A-0394 - Tierra Blanca  Paleocanal de Chicontepec   Juan Felipe
# 4 2017-09-01  A-0394 - Tierra Blanca  Paleocanal de Chicontepec   Juan Felipe
#
#          nombre_pozo clasificacion        api  petroleo_mbd  gas_asoc_mmpcd  \
# 0  Cerro Viejo-406--    Asignaci�n  20.000000      0.085000        0.047724
# 1   Cerro Viejo-52--    Asignaci�n  20.000000      0.047000        0.017680
# 2        Gallo-425--    Asignaci�n  13.095138      0.000000        0.000000
# 3  Juan Felipe-127-A    Asignaci�n  21.000000      0.011300        0.006344
# 4  Juan Felipe-142--    Asignaci�n  21.000000      0.009633        0.005409
#
# ...
